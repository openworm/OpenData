# %% [markdown]
# <a href="https://colab.research.google.com/github/openworm/OpenData/blob/master/standard_worm/scripts/6wormplots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import sys
import numpy as np
import h5py
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/EST09/AccessibleData/master/30072019_redworm_roi.csv"
redwormneurons = pd.read_csv(url)
url2 = "https://raw.githubusercontent.com/openworm/OpenData/master/standard_worm/worm_1/worm1transformedontoredworm.csv"
worm105082019 = pd.read_csv(url2, names = ["X", "Y", "Slice"])
url3 = "https://raw.githubusercontent.com/openworm/OpenData/master/standard_worm/worm3/05082019_worm3red.csv"
worm305082019 = pd.read_csv(url3, names = ["X", "Y", "Slice"])
url4 = "https://raw.githubusercontent.com/openworm/OpenData/master/standard_worm/worm4/05082019_worm4red.csv"
worm405082019 = pd.read_csv(url4, names = ["X", "Y", "Slice"])
url5 = "https://raw.githubusercontent.com/openworm/OpenData/master/standard_worm/worm5/05082019_worm5red.csv"
worm505082019 = pd.read_csv(url5, names = ["X", "Y", "Slice"])
url6 = "https://raw.githubusercontent.com/openworm/OpenData/master/standard_worm/worm6/05082019_worm6red.csv"
worm605082019 = pd.read_csv(url6, names = ["X", "Y", "Slice"])


# #assuming that slice 0 is the starting point of imaging 

newSlice = redwormneurons['Slice']
newSlice*=3.520000112640004
redwormneurons["NewSlice"] = newSlice

newSlice = worm105082019['Slice']
newSlice*=3.520000112640004
worm105082019["NewSlice"] = newSlice

newSlice = worm305082019['Slice']
newSlice*=3.520000112640004
worm305082019["NewSlice"] = newSlice

newSlice = worm405082019['Slice']
newSlice*=3.520000112640004
worm405082019["NewSlice"] = newSlice

newSlice = worm505082019['Slice']
newSlice*=3.520000112640004
worm505082019["NewSlice"] = newSlice

newSlice = worm605082019['Slice']
newSlice*=3.520000112640004
worm605082019["NewSlice"] = newSlice

# %%
def configure_plotly_browser_state():
   import IPython
   display(IPython.core.display.HTML('''
         <script src="/static/components/requirejs/require.js"></script>
         <script>
           requirejs.config({
             paths: {
               base: '/static/base',
               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
             },
           });
         </script>
         '''))
  
configure_plotly_browser_state()
# Out:
#          <script src="/static/components/requirejs/require.js"></script>
#          <script>
#            requirejs.config({
#              paths: {
#                base: '/static/base',
#                plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#              },
#            });
#          </script>

# %%
##ususally works in anaconda - not working in colab - need to fix

# from _plotly_future_ import v4_subplots
# import plotly
# from plotly.subplots import make_subplots
# import plotly.graph_objects as go

# fig = make_subplots(rows=2, cols=3)

# fig.add_trace(
#     go.Scatter(x=redwormneurons.X,  # <-- Put your data instead
#     y=redwormneurons.Y,
#     mode='markers',
#     marker={
#         'size': 3,
#         'opacity': 1,
#          #"color":'rgba(255, 0, 0, .8)'
#     }),
#     row = 1, col=1)
    
# fig.add_trace(
#     go.Scatter(x=worm105082019.X,  # <-- Put your data instead
#     y=worm105082019.Y,
#     mode='markers',
#     marker={
#         'size': 3,
#         'opacity': 1,
#          #"color":'rgba(255, 0, 0, .8)'
#     }),
#     row = 1, col=2)
    
# fig.add_trace(
#     go.Scatter(x=worm305082019.X,  # <-- Put your data instead
#     y=worm305082019.Y,
#     mode='markers',
#     marker={
#         'size': 3,
#         'opacity': 1,
#          #"color":'rgba(255, 0, 0, .8)'
#     }),
#     row = 1, col=3)
    
# fig.add_trace(
#     go.Scatter(x=worm405082019.X,  # <-- Put your data instead
#     y=worm405082019.Y,
#     mode='markers',
#     marker={
#         'size': 3,
#         'opacity': 1,
#          #"color":'rgba(255, 0, 0, .8)'
#     }),
#     row = 2, col=1)
    
# fig.add_trace(
#     go.Scatter(x=worm505082019.X,  # <-- Put your data instead
#     y=worm505082019.Y,
#     mode='markers',
#     marker={
#         'size': 3,
#         'opacity': 1,
#          #"color":'rgba(255, 0, 0, .8)'
#     }),
#     row = 2, col=2)
    
# fig.add_trace(
#     go.Scatter(x=worm605082019.X,  # <-- Put your data instead
#     y=worm605082019.Y,
#     mode='markers',
#     marker={
#         'size': 3,
#         'opacity': 1,
#          #"color":'rgba(255, 0, 0, .8)'
#     }),
#     row = 2, col=3)

# # layout = go.Layout(
# #         yaxis=dict(
# #             range=[3000, 4200]
# #         )
# #     )


# fig.update_layout(height=600, width=800, title_text="Subplots")
# fig.show()

# %%
configure_plotly_browser_state()
import plotly
import plotly.graph_objs as go

# Configure Plotly to be rendered inline in the notebook.
#plotly.offline.init_notebook_mode()

trace1 = go.Scatter3d(
    x=redwormneurons.X,  # <-- Put your data instead
    y=redwormneurons.Y,  # <-- Put your data instead
    z=redwormneurons.NewSlice,  # <-- Put your data instead
    mode='markers',
    marker={
        'size': 3,
        'opacity': 1,
         "color":'rgba(255, 0, 0, .8)'
    }
)

trace2 = go.Scatter3d(
    x=worm105082019.X,  # <-- Put your data instead
    y=worm105082019.Y,  # <-- Put your data instead
    z=worm105082019.NewSlice,  # <-- Put your data instead
    mode='markers',
    marker={
        'size': 3,
        'opacity': 1,
         "color":'rgba(0, 255, 0, .8)'
    }
)

trace3 = go.Scatter3d(
    x=worm305082019.X,  # <-- Put your data instead
    y=worm305082019.Y,  # <-- Put your data instead
    z=worm305082019.NewSlice,  # <-- Put your data instead
    mode='markers',
    marker={
        'size': 3,
        'opacity': 1,
         "color":'rgba(0, 0, 255, .8)'
    }
)

trace4 = go.Scatter3d(
    x=worm405082019.X,  # <-- Put your data instead
    y=worm405082019.Y,  # <-- Put your data instead
    z=worm405082019.NewSlice,  # <-- Put your data instead
    mode='markers',
    marker={
        'size': 3,
        'opacity': 1,
         "color":'rgba(255, 0, 255, .8)'
    }
)

trace5 = go.Scatter3d(
    x=worm505082019.X,  # <-- Put your data instead
    y=worm505082019.Y,  # <-- Put your data instead
    z=worm505082019.NewSlice,  # <-- Put your data instead
    mode='markers',
    marker={
        'size': 3,
        'opacity': 1,
         "color":'rgba(255, 255, 0, .8)'
    }
)

trace6 = go.Scatter3d(
    x=worm605082019.X,  # <-- Put your data instead
    y=worm605082019.Y,  # <-- Put your data instead
    z=worm605082019.NewSlice,  # <-- Put your data instead
    mode='markers',
    marker={
        'size': 3,
        'opacity': 1,
         "color":'rgba(0, 255, 255, .8)'
    }
)





# Configure the layout.
layout = go.Layout(
    margin={'l': 0, 'r': 0, 'b': 0, 't': 0}
)

data = [trace1, trace2, trace3, trace4, trace5, trace6]

layout = go.Layout(
             scene=dict(
                 aspectmode='data'
         ))

plot_figure = go.Figure(data=data, layout=layout)

# Render the plot.
plotly.offline.iplot(plot_figure)
# Out:
#          <script src="/static/components/requirejs/require.js"></script>
#          <script>
#            requirejs.config({
#              paths: {
#                base: '/static/base',
#                plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#              },
#            });
#          </script>
# ...
